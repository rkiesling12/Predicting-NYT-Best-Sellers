# %%
import requests

# %%
#response = requests.get("https://api.nytimes.com/svc/books/v3/lists/names.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD")

# %%
#print(response.json())

# %%
response = requests.get("https://api.nytimes.com/svc/books/v3/lists/2020-01-26/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD")

# %%
import json
with open('nyt.txt', 'w') as outfile:
    json.dump(response.json()["results"]['books'], outfile)

# %%
import pandas as pd
df = pd.read_json('nyt.txt')

# %%
response = requests.get("https://api.nytimes.com/svc/books/v3/lists/2020-01-19/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD")

# %%
with open('nyt2.txt', 'w') as outfile:
    json.dump(response.json()["results"]['books'], outfile)

# %%
df2 = pd.read_json('nyt2.txt')
df_full = pd.concat([df, df2])

# %%
from time import sleep
dates = ["2020-01-12", "2020-01-07", "2019-01-06", "2019-01-13", "2019-01-20", "2019-01-27", "2019-02-03", "2019-02-10",
        "2019-02-17", "2019-02-24", "2019-03-03", "2019-03-10", "2019-03-17", "2019-03-24", "2019-03-31", "2019-04-07",
        "2019-04-14", "2019-04-21", "2019-04-28", "2019-05-05", "2019-05-12", "2019-05-19", "2019-05-26", "2019-06-02",
        "2019-06-09", "2019-06-16", "2019-06-23", "2019-06-30", "2019-07-07", "2019-07-14", "2019-07-21", "2019-07-28", 
        "2019-08-04", "2019-08-11", "2019-08-18", "2019-08-25", "2019-09-01", "2019-09-08", "2019-09-15", "2019-09-22",
        "2019-09-29", "2019-10-06", "2019-10-13", "2019-10-20", "2019-10-27", "2019-11-03", "2019-11-10", "2019-11-17",
        "2019-11-24", "2019-12-01", "2019-12-08", "2019-12-15", "2019-12-22", "2019-12-29", "2018-01-07", "2018-01-14",
        "2018-01-21", "2018-01-28", "2018-02-04", "2018-02-11", "2018-02-19", "2018-02-25", "2018-03-04", "2018-03-11", 
        "2018-03-18", "2018-03-25", "2018-04-01", "2018-04-08", "2018-04-15", "2018-04-22", "2018-04-29", "2018-04-06", 
        "2018-04-13", "2018-04-20", "2018-04-27", "2018-05-06", "2018-05-13", "2018-05-20", "2018-05-27", "2018-06-03",
        "2018-06-10", "2018-06-17", "2018-06-24", "2018-07-01", "2018-07-08", "2018-07-15", "2018-07-22", "2018-07-29",
        "2018-08-05", "2018-08-12", "2018-08-19", "2018-08-26", "2018-09-02", "2018-09-09", "2018-09-16", "2018-09-23",
        "2018-09-30", "2018-10-07", "2018-10-14", "2018-10-21", "2018-10-28", "2018-11-04", "2018-11-11", "2018-11-18",
        "2018-11-25", "2018-12-02", "2018-12-09", "2018-12-16", "2018-12-23", "2018-12-30", "2017-01-01", "2017-01-08",
        "2017-01-15", "2017-01-22", "2017-01-29", "2017-02-05", "2017-02-12", "2017-02-19", "2017-02-26", "2017-03-05",
        "2017-03-12", "2017-03-19", "2017-03-26", "2017-04-02", "2017-04-09", "2017-04-16", "2017-04-23", "2017-04-30",
        "2017-05-07", "2017-05-14", "2017-05-21", "2017-05-28", "2017-06-04", "2017-06-11", "2017-06-18", "2017-06-25",
        "2017-07-02", "2017-07-09", "2017-07-16", "2017-07-23", "2017-07-30", "2017-08-06", "2017-08-13", "2017-08-20",
        "2017-08-27", "2017-09-03", "2017-09-10", "2017-09-17", "2017-09-24", "2017-10-01", "2017-10-08", "2017-10-15",
        "2017-10-22", "2017-10-29", "2017-11-05", "2017-11-12", "2017-11-19", "2017-11-26", "2017-12-03", "2017-12-10",
        "2017-12-17", "2017-12-24", "2017-12-31", "2016-01-03", "2016-01-10", "2016-01-17", "2016-01-24", "2016-01-31",
        "2016-02-07", "2016-02-14", "2016-02-21", "2016-02-28", "2016-03-06", "2016-03-13", "2016-03-20", "2016-03-27",
        "2016-04-03", "2016-04-10", "2016-04-17", "2016-04-24", "2016-05-01", "2016-05-08", "2016-05-15", "2016-05-22",
        "2016-05-29", "2016-06-05", "2016-06-12", "2016-06-19", "2016-06-26", "2016-07-03", "2016-07-10", "2016-07-17",
        "2016-07-24", "2016-07-31", "2016-08-07", "2016-08-14", "2016-08-21", "2016-08-28", "2016-09-04", "2016-09-11",
        "2016-09-18", "2016-09-25", "2016-10-02", "2016-10-09", "2016-10-16", "2016-10-23", "2016-10-30", "2016-11-06",
        "2016-11-13", "2016-11-20", "2016-11-27", "2016-12-04", "2016-12-11", "2016-12-18", "2016-12-25", "2015-09-06", 
         "2015-09-13", "2015-09-20", "2015-09-27", "2015-10-04", "2015-10-11",
        "2015-10-18", "2015-10-25", "2015-11-01", "2015-11-08", "2015-11-15", "2015-11-22", "2015-11-29", "2015-12-06",
        "2015-12-13", "2015-12-20", "2015-12-27", ]
for date in dates:
    url = "https://api.nytimes.com/svc/books/v3/lists/"+date+"/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD"
    print(url)
    response = requests.get(url)
    with open('nyt2.txt', 'w') as outfile:
        json.dump(response.json()["results"]['books'], outfile)
    df2 = pd.read_json('nyt2.txt')
    df_full = pd.concat([df_full, df2])
    sleep(7)
# Out:
# https://api.nytimes.com/svc/books/v3/lists/2020-01-12/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD
# https://api.nytimes.com/svc/books/v3/lists/2020-01-07/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD
# https://api.nytimes.com/svc/books/v3/lists/2019-01-06/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD
# https://api.nytimes.com/svc/books/v3/lists/2019-01-13/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD
# https://api.nytimes.com/svc/books/v3/lists/2019-01-20/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD
# https://api.nytimes.com/svc/books/v3/lists/2019-01-27/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD
# https://api.nytimes.com/svc/books/v3/lists/2019-02-03/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD
# https://api.nytimes.com/svc/books/v3/lists/2019-02-10/young-adult-hardcover.json?api-key=ZmiGgqSrOERXfFjSjR3vrnesRgFBOJsD
# ...

# %%
df_full
# Out:
#     rank  rank_last_week  weeks_on_list  asterisk  dagger primary_isbn10  \
# 0      1               0              1         0       0      525707964
# 1      2               1              6         0       0     1250170990
# 2      3               3            150         0       0       62498533
# 3      4               2             97         0       0     1250170974
# 4      5               0              1         0       0     1250246075
# ..   ...             ...            ...       ...     ...            ...
# 5      6               0             17         0       0           None
# 6      7               0              8         0       0     0553499114
# 7      8               0             14         0       0     0553496646
# 8      9               0             11         0       0     0385755880
# 9     10               0              1         0       0     076367818X
#
#     primary_isbn13             publisher  \
# 0    9780525707967             Delacorte
# ...

# %%
df_full.to_csv('nyt_paper_yahard.csv')
